# %%
import sys
sys.executable
# Out:
# '/home/jovyan/work/CellSense/X20251016-CellSense-VB/cell/bin/python'

# %%
cd ..
# Out:
# /home/jovyan/work/BioRAG

# %%
pip install -e .
# Out:
# Obtaining file:///home/jovyan/work/BioRAG
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for BioRAG (pyproject.toml) ... done
#   Created wheel for BioRAG: filename=biorag-0.0.1-0.editable-py3-none-any.whl size=2936 sha256=af49e7d5840908ad74d00718ce684e42338cebaf4375a91956c7453b792fe261
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k87crhth/wheels/24/8a/b6/dfad71ff8d6f29e714ba3d85f597dbcddecbc836e98fc527fc
# Successfully built BioRAG
# ...
#   Attempting uninstall: BioRAG
#     Found existing installation: BioRAG 0.0.1
#     Uninstalling BioRAG-0.0.1:
#       Successfully uninstalled BioRAG-0.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python scripts/Generation.py
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/work/BioRAG/scripts/Generation.py", line 1, in <module>
#     from generation.query_rewrite import QueryRewriter
# ModuleNotFoundError: No module named 'generation'

# %%
# !nvidia-smi
# Out:
# Fri Jan 23 20:34:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.124.06             Driver Version: 570.124.06     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  |   00000000:CA:00.0 Off |                    0 |
# | N/A   38C    P0            321W /  300W |   26687MiB /  81920MiB |      3%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import torch
torch.cuda.empty_cache()
